# %% [markdown]
# ## NB: Aula 05 - Regressao Linear

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
teste = None
treino = None


teste = pd.read_csv('https://raw.githubusercontent.com/lcbjrrr/DSforBusiness/refs/heads/main/log_test.csv')
treino = pd.read_csv('https://raw.githubusercontent.com/lcbjrrr/DSforBusiness/refs/heads/main/log_train.csv')
np.set_printoptions(precision=2, suppress=True)
print(LinearRegression().fit(treino[["time_page_seg","duration","sessions","pags_sess","conv"]], treino["value"]).predict(teste[["time_page_seg","duration","sessions","pags_sess","conv"]]))
# Out:
# [ 5.56  4.93 92.04 84.59 -3.06 84.34 -6.46  3.53 -6.46  4.25  2.1  -5.75
#  -7.18 -6.46  5.67 -0.04 -0.04 -6.46  2.82 -7.18  4.25  1.39 -2.89  3.53
#   3.53 -6.46 -5.75 -5.75 -4.32 -5.03 -0.04 -5.75 -7.18  2.1  -3.67 54.37
#   3.53 -7.18  4.96 -5.03  0.68  2.82 -0.04  4.96  2.82 -0.75  3.53 -2.89
#  -0.04 -0.75  4.96  3.53 -7.18 -5.81  2.1   4.96 -2.18 -3.61  4.25 -3.61
#  49.37 50.09 47.94 48.66 50.8  56.51 -3.61 56.51  5.67 59.37 -4.32 -5.03
#   2.82 -6.46 -3.67 -2.18  6.39  4.25 -0.04 -3.61  4.96  0.68  0.68 -6.46
#  -2.96  5.67  4.25  1.39 47.23 51.51  5.67 52.23 -0.04 57.94 56.51 -0.75
#  88.64 95.06 84.35 55.8   5.04  2.8   2.1  -2.24 52.34 54.35 52.29  0.03
#   2.28  4.43  2.18 -1.32 54.35 -6.2  -1.4   0.21 -5.92  4.23 -1.4  -7.24
#   2.14 -5.86  0.65 94.18 82.45 -5.91 87.9  -5.03  1.39 -2.89  2.1  -3.61
#   4.25  2.1   2.1   1.39 -5.03  3.53]

# %% [markdown]
# ## Atividade: Regressao Linear

# %% [markdown]
# Usando Blockly crie uma Regressão Linear: https://quant-research.group/blockly_ds_dev/
#
# Existe alguma relação entre a cotação do dólar e o Índice Bovespa (IBOV)?
#
# Essa relação é diretamente proporcional (positiva) ou negativa?
#
# Qual a lógica econômica que explica essa relação?
#
# Então, crie sua máquina para prever o futuro do dólar com base na cotação do IBOV.
#
# Qual o valor da bolsa hoje? E do dólar? Se o IBOV atingir 100.000 pontos, qual o valor esperado do dólar?
#
#
#
# treino: https://raw.githubusercontent.com/lcbjrrr/DSforBusiness/refs/heads/main/usdbrl.csv
#
# teste:  https://raw.githubusercontent.com/lcbjrrr/DSforBusiness/refs/heads/main/usdbrl_ts.csv
